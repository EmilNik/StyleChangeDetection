# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest

# %%
df = pd.read_csv('../data/500_ngrams/train_features_scaled_standard.csv', index_col=0)

# %%
df_feature_names = pd.read_csv('../data/500_ngrams/feature_names.csv', index_col=0)

# %%
N = int((len(df.columns) - 1) / 2)

df_train_a = df.iloc[:, :N]
df_train_b = df.iloc[:, N:-1]

df_train_a = df_train_a.rename(columns={x:y for x,y in zip(df_train_a.columns,range(0,len(df_train_a.columns)))})
df_train_b = df_train_b.rename(columns={x:y for x,y in zip(df_train_b.columns,range(0,len(df_train_b.columns)))})

# %%
df_train_absdiff = abs(df_train_a - df_train_b)

# %%
y_train = list(map(lambda y: int(y), df['different_author']))

# %%
selector = SelectKBest(k=100)

# %%
selector.fit(df_train_absdiff, y_train)
# Out:
# /Users/peterstefanov/py3-playground-env/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [  6   7  25  27  34 114 121 167 191 366 372 493 494 515 662 663 668] are constant.
#   UserWarning)
# /Users/peterstefanov/py3-playground-env/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# SelectKBest(k=100, score_func=<function f_classif at 0x10de58bf8>)

# %%
idxs = selector.get_support(indices=True)
idxs
# Out:
# array([  1,   5,  10,  23,  24,  29,  30,  32,  33,  36,  64,  65,  71,
#         72,  73,  74, 104, 105, 112, 120, 122, 123, 146, 161, 177, 181,
#        188, 226, 235, 239, 247, 250, 252, 260, 262, 266, 300, 301, 307,
#        308, 314, 315, 324, 338, 349, 355, 369, 390, 399, 400, 406, 412,
#        413, 414, 429, 442, 459, 460, 469, 470, 487, 491, 492, 501, 506,
#        511, 512, 529, 533, 537, 539, 556, 574, 581, 582, 588, 592, 602,
#        605, 624, 627, 630, 632, 648, 652, 656, 670, 673, 687, 706, 710,
#        737, 748, 768, 782, 796, 800, 816, 817, 823])

# %%
df_feature_names.iloc[idxs]
# Out:
#                              0
# 1                    Ari Index
# 5           Coleman Liau Index
# 10                    DT_JJ_NN
# 23   Dale Chall Known Fraction
# 24            Dale Chall Score
# 29        Flesch Kincaid Grade
# 30         Flesch Reading Ease
# 32           Gunning Fog Index
# 33                           H
# 36                    IN_DT_JJ
# 64           Lexical diversity
# 65                   Lix Index
# 71        Mean Sentence Length
# 72            Mean Word Length
# 73       Mean paragraph Length
# 74     Mean syllables per word
# 104          Number of letters
# 105                    Numbers
# 112                Punctuation
# 120      STDEV Sentence Length
# 122                 Smog Index
# 123         Special characters
# 146  Words with >= 3 syllables
# 161                       acti
# 177                       ampl
# 181                       ange
# 188                       appr
# 226                       book
# 235                       cent
# 239                       chan
# ..                         ...
# 539                       obje
# 556                       onsi
# 574                       ount
# 581                       owev
# 582                       owin
# 588                       pect
# 592                       pers
# 602                       pres
# 605                       prop
# 624                       refe
# 627                       renc
# 630                       rese
# 632                       ress
# 648                       rson
# 652                       rule
# 656                       scri
# 670                       show
# 673                       side
# 687                       stan
# 706                       tack
# 710                       tand
# 737                       thin
# 748                       tion
# 768                       umbe
# 782                       vide
# 796                       weve
# 800                      which
# 816                       writ
# 817                       xamp
# 823                        you
#
# [100 rows x 1 columns]
